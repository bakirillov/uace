# %%
import os
import json
import argparse
import numpy as np
import pandas as pd
import os.path as op
from core import in_CI, rsquared
from scipy.stats import spearmanr, pearsonr

# %%
Table1 = pd.read_csv("Table1.csv", index_col=0)

# %%
Table2 = Table1.loc[["Cpf1" in a or "Cas12" in a for a in Table1.index]]

# %%
Table2.to_csv("Table2.csv")

# %%
Table2
# Out:
#                                       0.68      0.95     0.997       PCC  \
# DeepCpf1 RNN ELBO:H1              0.688854  0.947368  0.994582  0.738202
# DeepCpf1 CNN MSE ELBO:H2          0.678029  0.927776  0.993925  0.718174
# DeepCpf1 CNN ELBO:H1              0.667957  0.930341  0.990712  0.724603
# DeepCpf1 CNN ELBO:H2              0.679717  0.930476  0.992913  0.712728
# DeepCpf1 CNN MSE ELBO:H1          0.665635  0.926471  0.989938  0.720037
# DeepCpf1 RNN ELBO:H2              0.705029  0.948026  0.995613  0.710777
# DeepCpf1 RNN MSE ELBO:H1          0.701238  0.964396  0.999226  0.719289
# DeepCpf1 RNN MSE ELBO:H2          0.714816  0.953763  0.999663  0.668010
# Cas12a gRNA-target pair ELBO      0.593750  0.868750  0.956250  0.569292
# Cas12a gRNA-target pair MSE ELBO  0.587500  0.862500  0.962500  0.558500
# DeepCpf1 RNN ELBO:H3              0.266986  0.667466  0.945643  0.506106
# DeepCpf1 CNN ELBO:H3              0.250200  0.631495  0.917666  0.500468
# DeepCpf1 CNN MSE ELBO:H3          0.242206  0.623501  0.908873  0.487341
# DeepCpf1 RNN MSE ELBO:H3          0.308553  0.726619  0.996803  0.417804
#
#                                        PCC-pval       SCC       SCC-pval  \
# DeepCpf1 RNN ELBO:H1              8.538533e-223  0.728282  5.648499e-214
# DeepCpf1 CNN MSE ELBO:H2           0.000000e+00  0.718374   0.000000e+00
# DeepCpf1 CNN ELBO:H1              8.408238e-211  0.715848  1.865789e-203
# DeepCpf1 CNN ELBO:H2               0.000000e+00  0.710767   0.000000e+00
# DeepCpf1 CNN MSE ELBO:H1          6.173833e-207  0.709996  1.064616e-198
# DeepCpf1 RNN ELBO:H2               0.000000e+00  0.704773   0.000000e+00
# DeepCpf1 RNN MSE ELBO:H1          2.611461e-206  0.703781  8.935305e-194
# DeepCpf1 RNN MSE ELBO:H2           0.000000e+00  0.659238   0.000000e+00
# Cas12a gRNA-target pair ELBO       4.001013e-15  0.574276   2.032146e-15
# Cas12a gRNA-target pair MSE ELBO   1.669153e-14  0.566603   5.738641e-15
# DeepCpf1 RNN ELBO:H3               2.474894e-82  0.547773   7.184815e-99
# DeepCpf1 CNN ELBO:H3               2.880539e-80  0.527163   2.111442e-90
# DeepCpf1 CNN MSE ELBO:H3           1.327417e-75  0.510992   3.724687e-84
# DeepCpf1 RNN MSE ELBO:H3           5.023135e-54  0.457113   1.317584e-65
#
#                                   rsquared
# DeepCpf1 RNN ELBO:H1              0.544942
# DeepCpf1 CNN MSE ELBO:H2          0.515775
# DeepCpf1 CNN ELBO:H1              0.525049
# DeepCpf1 CNN ELBO:H2              0.507981
# DeepCpf1 CNN MSE ELBO:H1          0.518453
# DeepCpf1 RNN ELBO:H2              0.505204
# DeepCpf1 RNN MSE ELBO:H1          0.517376
# DeepCpf1 RNN MSE ELBO:H2          0.446238
# Cas12a gRNA-target pair ELBO      0.324093
# Cas12a gRNA-target pair MSE ELBO  0.311922
# DeepCpf1 RNN ELBO:H3              0.256143
# DeepCpf1 CNN ELBO:H3              0.250468
# DeepCpf1 CNN MSE ELBO:H3          0.237501
# DeepCpf1 RNN MSE ELBO:H3          0.174560
