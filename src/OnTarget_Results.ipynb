# %%
import os
import numpy as np
import pandas as pd
import os.path as op

# %%
singles = [a for a in os.walk("../results/on-target")][0][2]
data = pd.concat(
    [pd.read_csv(op.join("../results/on-target", a), index_col=0) for a in singles]
)
data.index = [" ".join(a.split("_")[2:]).replace(".csv", "") for a in singles]
data = data.sort_values(by="SCC", ascending=False)

# %%
data
# Out:
#                                   0.68      0.95     0.997       PCC  \
# DeepHF Wt rnn mse             0.753477  0.942206  0.983453  0.875056
# DeepHF Wt cnn mse             0.761271  0.944964  0.985252  0.867180
# DeepHF Wt cnn elbo            0.761631  0.948321  0.985731  0.866801
# DeepHF Wt rnn elbo            0.774101  0.952158  0.986691  0.867936
# DeepHF SpCas9HF1 cnn mse      0.696004  0.945974  0.988515  0.846856
# ...                                ...       ...       ...       ...
# DeepCRISPR hct116 rnn mse v   0.976048  1.000000  1.000000 -0.024260
# DeepCRISPR hek293t rnn elbo   0.721389  0.949850  1.000000 -0.129191
# DeepCRISPR hek293t cnn mse    0.681955  0.912988  1.000000 -0.148641
# DeepCRISPR hek293t rnn mse    0.734676  0.959280  1.000000 -0.195042
# DeepCRISPR hek293t rnn mse v  1.000000  1.000000  1.000000       NaN
#
#                                   PCC-pval       SCC      SCC-pval  rsquared
# DeepHF Wt rnn mse             0.000000e+00  0.844582  0.000000e+00  0.765723
# DeepHF Wt cnn mse             0.000000e+00  0.837167  0.000000e+00  0.752001
# DeepHF Wt cnn elbo            0.000000e+00  0.836355  0.000000e+00  0.751344
# DeepHF Wt rnn elbo            0.000000e+00  0.835687  0.000000e+00  0.753314
# DeepHF SpCas9HF1 cnn mse      0.000000e+00  0.832717  0.000000e+00  0.717165
# ...                                    ...       ...           ...       ...
# DeepCRISPR hct116 rnn mse v   4.838820e-01 -0.033430  3.346251e-01  0.000589
# DeepCRISPR hek293t rnn elbo   3.776603e-10 -0.113162  4.240096e-08  0.016690
# DeepCRISPR hek293t cnn mse    5.362176e-13 -0.147643  7.676697e-13  0.022094
# DeepCRISPR hek293t rnn mse    1.959766e-21 -0.150975  2.294103e-13  0.038041
# DeepCRISPR hek293t rnn mse v           NaN       NaN           NaN       NaN
#
# [62 rows x 8 columns]

# %%
data[["DeepCpf1" in a for a in data.index]]
# Out:
#                              0.68      0.95     0.997       PCC  \
# DeepCpf1Kim rnn mse H1   0.698916  0.945820  0.995356  0.745043
# DeepCpf1Kim cnn elbo H2  0.686466  0.934526  0.993925  0.716860
# DeepCpf1Kim cnn mse H2   0.690516  0.932163  0.992238  0.716954
# DeepCpf1Kim rnn mse H2   0.701991  0.941951  0.995275  0.718812
# DeepCpf1Kim cnn mse H1   0.668731  0.931889  0.991486  0.724138
# DeepCpf1Kim cnn elbo H1  0.660217  0.932663  0.991486  0.718770
# DeepCpf1Kim rnn mse H3   0.265388  0.660272  0.944045  0.514103
# DeepCpf1Kim cnn elbo H3  0.254197  0.621902  0.912070  0.495622
# DeepCpf1Kim cnn mse H3   0.254996  0.621103  0.908074  0.491255
# DeepCpf1Kim rnn elbo H2  0.650692  1.000000  1.000000  0.045543
# DeepCpf1Kim rnn elbo H3  0.693845  1.000000  1.000000  0.059490
# DeepCpf1Kim rnn elbo H1  0.548762  1.000000  1.000000  0.042487
#
#                               PCC-pval       SCC       SCC-pval  rsquared
# DeepCpf1Kim rnn mse H1   4.080083e-229  0.738497  4.602043e-223  0.555088
# DeepCpf1Kim cnn elbo H2   0.000000e+00  0.716108   0.000000e+00  0.513888
# DeepCpf1Kim cnn mse H2    0.000000e+00  0.715506   0.000000e+00  0.514023
# DeepCpf1Kim rnn mse H2    0.000000e+00  0.714922   0.000000e+00  0.516691
# DeepCpf1Kim cnn mse H1   2.098459e-210  0.713808  8.753936e-202  0.524375
# DeepCpf1Kim cnn elbo H1  7.077374e-206  0.709212  4.522190e-198  0.516630
# DeepCpf1Kim rnn mse H3    2.484876e-85  0.550932  3.204010e-100  0.264302
# DeepCpf1Kim cnn elbo H3   1.601932e-78  0.524625   2.123974e-89  0.245642
# DeepCpf1Kim cnn mse H3    5.670886e-77  0.520008   1.349230e-87  0.241332
# DeepCpf1Kim rnn elbo H2   1.316442e-02  0.042113   2.188148e-02  0.002074
# DeepCpf1Kim rnn elbo H3   3.538739e-02  0.039618   1.613835e-01  0.003539
# DeepCpf1Kim rnn elbo H1   1.269156e-01  0.037833   1.741254e-01  0.001805

# %%
data.to_csv("total.csv")
