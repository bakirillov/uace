# %%
import os
import numpy as np
import pandas as pd
import os.path as op

# %%
singles = [a for a in os.walk("../results/on-target")][0][2]
data = pd.concat(
    [pd.read_csv(op.join("../results/on-target", a), index_col=0) for a in singles]
)
data.index = [" ".join(a.split("_")[2:]).replace(".csv", "") for a in singles]

# %%
data
# Out:
#                                    0.68      0.95     0.997       PCC  \
# DeepCRISPR hct116 rnn elbo     0.698706  0.957574  0.995206  0.378250
# DeepHF SpCas9HF1 cnn mse       0.696004  0.945974  0.988515  0.846856
# DeepCpf1Kim rnn elbo H3        0.693845  1.000000  1.000000  0.059490
# DeepCpf1Kim rnn elbo H2        0.650692  1.000000  1.000000  0.045543
# DeepCRISPR hek293t rnn elbo v  1.000000  1.000000  1.000000  0.033775
# ...                                 ...       ...       ...       ...
# Weissman cnn mse               0.717611  0.912421  0.980347  0.791178
# DeepHF SpCas9HF1 rnn elbo      0.645611  0.917497  0.980898  0.833818
# DeepHF SpCas9HF1 rnn mse       0.666823  0.921598  0.981952  0.848052
# DeepCRISPR hek293t rnn mse     0.734676  0.959280  1.000000 -0.195042
# DeepCRISPR hl60 rnn mse v      1.000000  1.000000  1.000000  0.090779
#
#                                     PCC-pval       SCC       SCC-pval  \
# DeepCRISPR hct116 rnn elbo     5.023812e-142  0.367793  8.313784e-134
# DeepHF SpCas9HF1 cnn mse        0.000000e+00  0.832717   0.000000e+00
# DeepCpf1Kim rnn elbo H3         3.538739e-02  0.039618   1.613835e-01
# DeepCpf1Kim rnn elbo H2         1.316442e-02  0.042113   2.188148e-02
# DeepCRISPR hek293t rnn elbo v   4.665353e-01  0.017502   7.059929e-01
# ...                                      ...       ...            ...
# Weissman cnn mse                0.000000e+00  0.706660   0.000000e+00
# DeepHF SpCas9HF1 rnn elbo       0.000000e+00  0.819264   0.000000e+00
# DeepHF SpCas9HF1 rnn mse        0.000000e+00  0.832315   0.000000e+00
# DeepCRISPR hek293t rnn mse      1.959766e-21 -0.150975   2.294103e-13
# DeepCRISPR hl60 rnn mse v       6.903383e-02  0.060998   2.223344e-01
#
#                                rsquared
# DeepCRISPR hct116 rnn elbo     0.143073
# DeepHF SpCas9HF1 cnn mse       0.717165
# DeepCpf1Kim rnn elbo H3        0.003539
# DeepCpf1Kim rnn elbo H2        0.002074
# DeepCRISPR hek293t rnn elbo v  0.001141
# ...                                 ...
# Weissman cnn mse               0.625962
# DeepHF SpCas9HF1 rnn elbo      0.695252
# DeepHF SpCas9HF1 rnn mse       0.719192
# DeepCRISPR hek293t rnn mse     0.038041
# DeepCRISPR hl60 rnn mse v      0.008241
#
# [63 rows x 8 columns]

# %%
data[["Offtarget" in a for a in data.index]]
# Out:
#                          0.68    0.95  0.997       PCC      PCC-pval  \
# Cpf1Offtarget cnn elbo  0.575  0.8625   0.95  0.589067  2.540598e-16
#
#                              SCC      SCC-pval  rsquared
# Cpf1Offtarget cnn elbo  0.602641  3.425630e-17     0.347

# %%
data[["DeepHF" in a for a in data.index]]
# Out:
#                                0.68      0.95     0.997       PCC  PCC-pval  \
# DeepHF SpCas9HF1 cnn mse   0.696004  0.945974  0.988515  0.846856       0.0
# DeepHF Wt cnn mse          0.761271  0.944964  0.985252  0.867180       0.0
# DeepHF Wt rnn mse          0.753477  0.942206  0.983453  0.875056       0.0
# DeepHF eSpCas9 cnn mse     0.709736  0.943358  0.989308  0.817222       0.0
# DeepHF Wt cnn elbo         0.761631  0.948321  0.985731  0.866801       0.0
# DeepHF eSpCas9 rnn mse     0.710191  0.945519  0.990332  0.819886       0.0
# DeepHF Wt rnn elbo         0.774101  0.952158  0.986691  0.867936       0.0
# DeepHF eSpCas9 cnn elbo    0.712125  0.941197  0.989308  0.817471       0.0
# DeepHF SpCas9HF1 cnn elbo  0.689910  0.941404  0.989921  0.839731       0.0
# DeepHF eSpCas9 rnn elbo    0.651615  0.911283  0.979754  0.813359       0.0
# DeepHF SpCas9HF1 rnn elbo  0.645611  0.917497  0.980898  0.833818       0.0
# DeepHF SpCas9HF1 rnn mse   0.666823  0.921598  0.981952  0.848052       0.0
#
#                                 SCC  SCC-pval  rsquared
# DeepHF SpCas9HF1 cnn mse   0.832717       0.0  0.717165
# DeepHF Wt cnn mse          0.837167       0.0  0.752001
# DeepHF Wt rnn mse          0.844582       0.0  0.765723
# DeepHF eSpCas9 cnn mse     0.821244       0.0  0.667852
# DeepHF Wt cnn elbo         0.836355       0.0  0.751344
# DeepHF eSpCas9 rnn mse     0.825115       0.0  0.672212
# DeepHF Wt rnn elbo         0.835687       0.0  0.753314
# DeepHF eSpCas9 cnn elbo    0.821813       0.0  0.668259
# DeepHF SpCas9HF1 cnn elbo  0.824660       0.0  0.705148
# DeepHF eSpCas9 rnn elbo    0.817733       0.0  0.661553
# DeepHF SpCas9HF1 rnn elbo  0.819264       0.0  0.695252
# DeepHF SpCas9HF1 rnn mse   0.832315       0.0  0.719192

# %%
data.to_csv("total.csv")

# %%
data.to_excel("ST3.xlsx")
